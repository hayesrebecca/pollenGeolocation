# %%
from itertools import cycle
import numpy as np
import matplotlib.pyplot as plt
import scipy
import pandas as pd
import xgboost as xgb
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler 
from sklearn.datasets import make_regression
from sklearn.multioutput import MultiOutputRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, roc_curve, auc
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from string import ascii_uppercase
from geopy.distance import geodesic

# %%
from src.cleaning_and_helpers import plot_test_preds

# %% [markdown]
# Import X and y from data prep steps

# %%
X = np.load('../pollenGeolocation_saved/X.npy')
y = np.load('../pollenGeolocation_saved/y.npy')

# %%
# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1298)

# Create scaler for X and y
sc_X = StandardScaler()
sc_y = StandardScaler()

# Scale training data
X_train = sc_X.fit_transform(X_train)
y_train = sc_y.fit_transform(y_train)  

# Scale test data using training parameters
X_test = sc_X.transform(X_test)
y_test = sc_y.transform(y_test)

# %%
X.shape
# Out:
# (1382, 182)

# %%
y.shape
# Out:
# (1382, 2)

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

# Update input shape for 182 features
input_dim = 182

# Define the updated MLP model
model = Sequential([
    Dense(256, activation='relu', input_shape=(input_dim,), kernel_regularizer=l2(0.01)),  # Input layer with L2 regularization
    Dense(128, activation='relu', kernel_regularizer=l2(0.01)),                            # Hidden layer
    Dropout(0.3),                                                                          # Dropout for regularization
    Dense(64, activation='relu', kernel_regularizer=l2(0.01)),                             # Hidden layer
    Dense(32, activation='relu', kernel_regularizer=l2(0.01)),                             # Hidden layer
    Dense(2)                                                                               # Output layer (2 targets)
])


# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])

# Early stopping callback to avoid overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=200,  # Increase epochs as needed
    batch_size=32,
    callbacks=[early_stopping],  # Use early stopping
    verbose=1
)

# Evaluate the model
loss, mae = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {loss:.4f}, Test MAE: {mae:.4f}")

# Make predictions
predictions = model.predict(X_test)
# Out:
# Epoch 1/200
# 28/28 [==============================] - 3s 59ms/step - loss: 5.2745 - mae: 0.6275 - val_loss: 4.3942 - val_mae: 0.3804
# Epoch 2/200
# 28/28 [==============================] - 0s 17ms/step - loss: 3.9201 - mae: 0.2699 - val_loss: 3.5450 - val_mae: 0.2052
# Epoch 3/200
# 28/28 [==============================] - 0s 7ms/step - loss: 3.2735 - mae: 0.2270 - val_loss: 3.0510 - val_mae: 0.1966
# Epoch 4/200
# 28/28 [==============================] - 0s 5ms/step - loss: 2.8193 - mae: 0.1878 - val_loss: 2.6308 - val_mae: 0.1649
# Epoch 5/200
# 28/28 [==============================] - 0s 4ms/step - loss: 2.4353 - mae: 0.1688 - val_loss: 2.2716 - val_mae: 0.1271
# Epoch 6/200
# 28/28 [==============================] - 0s 4ms/step - loss: 2.0891 - mae: 0.1291 - val_loss: 1.9822 - val_mae: 0.1207
# Epoch 7/200
# 28/28 [==============================] - 0s 10ms/step - loss: 1.8245 - mae: 0.1147 - val_loss: 1.7233 - val_mae: 0.1047
# Epoch 8/200
# 28/28 [==============================] - 0s 10ms/step - loss: 1.5989 - mae: 0.1121 - val_loss: 1.5391 - val_mae: 0.1256
# Epoch 9/200
# 28/28 [==============================] - 0s 4ms/step - loss: 1.3952 - mae: 0.1052 - val_loss: 1.3281 - val_mae: 0.0981
# Epoch 10/200
# 28/28 [==============================] - 0s 10ms/step - loss: 1.2119 - mae: 0.0929 - val_loss: 1.1701 - val_mae: 0.0966
# Epoch 11/200
# 28/28 [==============================] - 0s 11ms/step - loss: 1.0655 - mae: 0.0928 - val_loss: 1.0339 - val_mae: 0.0963
# Epoch 12/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.9331 - mae: 0.0883 - val_loss: 0.9056 - val_mae: 0.0909
# Epoch 13/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.8257 - mae: 0.0876 - val_loss: 0.8029 - val_mae: 0.0910
# Epoch 14/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.7270 - mae: 0.0842 - val_loss: 0.7253 - val_mae: 0.0963
# Epoch 15/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.6400 - mae: 0.0802 - val_loss: 0.6420 - val_mae: 0.0926
# Epoch 16/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.5658 - mae: 0.0772 - val_loss: 0.5795 - val_mae: 0.0979
# Epoch 17/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.5118 - mae: 0.0848 - val_loss: 0.5219 - val_mae: 0.0929
# Epoch 18/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4544 - mae: 0.0787 - val_loss: 0.4689 - val_mae: 0.0966
# Epoch 19/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4084 - mae: 0.0820 - val_loss: 0.4187 - val_mae: 0.0872
# Epoch 20/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.3667 - mae: 0.0793 - val_loss: 0.4044 - val_mae: 0.0933
# Epoch 21/200
# 28/28 [==============================] - 0s 7ms/step - loss: 0.3351 - mae: 0.0802 - val_loss: 0.3554 - val_mae: 0.0911
# Epoch 22/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.3104 - mae: 0.0855 - val_loss: 0.3454 - val_mae: 0.1013
# Epoch 23/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.2729 - mae: 0.0743 - val_loss: 0.3084 - val_mae: 0.0895
# Epoch 24/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.2491 - mae: 0.0728 - val_loss: 0.2877 - val_mae: 0.0918
# Epoch 25/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.2326 - mae: 0.0774 - val_loss: 0.2684 - val_mae: 0.0932
# Epoch 26/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.2111 - mae: 0.0727 - val_loss: 0.2473 - val_mae: 0.0854
# Epoch 27/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.1945 - mae: 0.0716 - val_loss: 0.2296 - val_mae: 0.0882
# Epoch 28/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.1780 - mae: 0.0695 - val_loss: 0.2196 - val_mae: 0.0888
# Epoch 29/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1659 - mae: 0.0689 - val_loss: 0.1968 - val_mae: 0.0816
# Epoch 30/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1556 - mae: 0.0699 - val_loss: 0.1879 - val_mae: 0.0839
# Epoch 31/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1455 - mae: 0.0683 - val_loss: 0.1873 - val_mae: 0.0872
# Epoch 32/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1349 - mae: 0.0637 - val_loss: 0.1861 - val_mae: 0.0883
# Epoch 33/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1289 - mae: 0.0699 - val_loss: 0.1671 - val_mae: 0.0878
# Epoch 34/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1224 - mae: 0.0682 - val_loss: 0.1655 - val_mae: 0.0827
# Epoch 35/200
# 28/28 [==============================] - 0s 8ms/step - loss: 0.1186 - mae: 0.0670 - val_loss: 0.1582 - val_mae: 0.0874
# Epoch 36/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1106 - mae: 0.0656 - val_loss: 0.1446 - val_mae: 0.0782
# Epoch 37/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.1130 - mae: 0.0726 - val_loss: 0.1562 - val_mae: 0.0886
# Epoch 38/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1109 - mae: 0.0756 - val_loss: 0.1353 - val_mae: 0.0872
# Epoch 39/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.1073 - mae: 0.0737 - val_loss: 0.1585 - val_mae: 0.0920
# Epoch 40/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1019 - mae: 0.0700 - val_loss: 0.1652 - val_mae: 0.0986
# Epoch 41/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0946 - mae: 0.0679 - val_loss: 0.1470 - val_mae: 0.0928
# Epoch 42/200
# 28/28 [==============================] - 0s 8ms/step - loss: 0.0936 - mae: 0.0711 - val_loss: 0.1512 - val_mae: 0.0945
# Epoch 43/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0908 - mae: 0.0706 - val_loss: 0.1332 - val_mae: 0.0860
# Epoch 44/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0877 - mae: 0.0655 - val_loss: 0.1290 - val_mae: 0.0851
# Epoch 45/200
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0827 - mae: 0.0643 - val_loss: 0.1368 - val_mae: 0.0897
# Epoch 46/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0848 - mae: 0.0684 - val_loss: 0.1283 - val_mae: 0.0900
# Epoch 47/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0798 - mae: 0.0665 - val_loss: 0.1292 - val_mae: 0.0944
# Epoch 48/200
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0769 - mae: 0.0652 - val_loss: 0.1211 - val_mae: 0.0870
# Epoch 49/200
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0781 - mae: 0.0729 - val_loss: 0.1182 - val_mae: 0.0869
# Epoch 50/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0768 - mae: 0.0659 - val_loss: 0.1224 - val_mae: 0.0883
# Epoch 51/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0781 - mae: 0.0692 - val_loss: 0.1219 - val_mae: 0.0914
# Epoch 52/200
# 28/28 [==============================] - 0s 8ms/step - loss: 0.0814 - mae: 0.0799 - val_loss: 0.1406 - val_mae: 0.1015
# Epoch 53/200
# 28/28 [==============================] - 0s 8ms/step - loss: 0.0772 - mae: 0.0699 - val_loss: 0.1400 - val_mae: 0.1078
# Epoch 54/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0723 - mae: 0.0701 - val_loss: 0.1313 - val_mae: 0.0853
# Epoch 55/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0704 - mae: 0.0616 - val_loss: 0.1300 - val_mae: 0.0915
# Epoch 56/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0734 - mae: 0.0714 - val_loss: 0.1364 - val_mae: 0.0919
# Epoch 57/200
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0715 - mae: 0.0713 - val_loss: 0.1210 - val_mae: 0.0836
# Epoch 58/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0690 - mae: 0.0647 - val_loss: 0.1140 - val_mae: 0.0903
# Epoch 59/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0670 - mae: 0.0628 - val_loss: 0.1066 - val_mae: 0.0812
# Epoch 60/200
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0647 - mae: 0.0604 - val_loss: 0.1140 - val_mae: 0.0861
# Epoch 61/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0651 - mae: 0.0650 - val_loss: 0.1043 - val_mae: 0.0814
# Epoch 62/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0666 - mae: 0.0715 - val_loss: 0.1071 - val_mae: 0.0860
# Epoch 63/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0654 - mae: 0.0681 - val_loss: 0.1087 - val_mae: 0.0866
# Epoch 64/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0636 - mae: 0.0622 - val_loss: 0.0985 - val_mae: 0.0799
# Epoch 65/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0639 - mae: 0.0656 - val_loss: 0.1122 - val_mae: 0.0840
# Epoch 66/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0620 - mae: 0.0607 - val_loss: 0.1109 - val_mae: 0.0852
# Epoch 67/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0624 - mae: 0.0627 - val_loss: 0.1041 - val_mae: 0.0913
# Epoch 68/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0628 - mae: 0.0665 - val_loss: 0.1153 - val_mae: 0.0924
# Epoch 69/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0624 - mae: 0.0672 - val_loss: 0.0914 - val_mae: 0.0790
# Epoch 70/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0652 - mae: 0.0720 - val_loss: 0.1261 - val_mae: 0.0933
# Epoch 71/200
# 28/28 [==============================] - 0s 8ms/step - loss: 0.0613 - mae: 0.0658 - val_loss: 0.1264 - val_mae: 0.0985
# Epoch 72/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0608 - mae: 0.0639 - val_loss: 0.1199 - val_mae: 0.0844
# Epoch 73/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0592 - mae: 0.0608 - val_loss: 0.1201 - val_mae: 0.0895
# Epoch 74/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0585 - mae: 0.0615 - val_loss: 0.1090 - val_mae: 0.0814
# Epoch 75/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0593 - mae: 0.0609 - val_loss: 0.1033 - val_mae: 0.0834
# Epoch 76/200
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0582 - mae: 0.0603 - val_loss: 0.1073 - val_mae: 0.0823
# Epoch 77/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0602 - mae: 0.0663 - val_loss: 0.1045 - val_mae: 0.0852
# Epoch 78/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0562 - mae: 0.0569 - val_loss: 0.1027 - val_mae: 0.0869
# Epoch 79/200
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0579 - mae: 0.0632 - val_loss: 0.0945 - val_mae: 0.0972
# Test Loss: 0.4827, Test MAE: 0.1242
# 9/9 [==============================] - 0s 1ms/step

# %%
# Create a figure and an axis
fig, ax = plt.subplots(figsize=(8, 6))

plot_test_preds(y_test, predictions, sc_y, "MLP",ax=ax)

# %%
import keras_tuner as kt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

def build_model(hp):
    model = Sequential()
    model.add(Dense(
        units=hp.Choice('units_layer1', [64, 128, 256]),
        activation='relu',
        input_shape=(182,)
    ))
    model.add(Dropout(hp.Choice('dropout_rate', [0.2, 0.3, 0.4])))

    for i in range(hp.Int('num_layers', 2, 4)):
        model.add(Dense(
            units=hp.Choice(f'units_layer{i+2}', [64, 128, 256]),
            activation='relu'
        ))
        model.add(Dropout(hp.Choice(f'dropout_rate_layer{i+2}', [0.2, 0.3, 0.4])))

    model.add(Dense(2))  # Output layer
    model.compile(
        optimizer=Adam(hp.Choice('learning_rate', [0.01, 0.001, 0.0001])),
        loss='mse',
        metrics=['mae']
    )
    return model

# Initialize tuner
tuner = kt.Hyperband(
    build_model,
    objective='val_loss',
    max_epochs=50,
    factor=3,
    directory='mlp_tuning',
    project_name='pollen_geolocation'
)

# Run the hyperparameter search
tuner.search(X_train, y_train, validation_split=0.2, epochs=200, verbose=1)

# Get the best model
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print("Best Hyperparameters:", best_hps.values)

# Train the best model
model = tuner.hypermodel.build(best_hps)
model.fit(X_train, y_train, validation_split=0.2, epochs=200)
# Out:
# Trial 88 Complete [00h 00m 21s]
# val_loss: 0.1355130821466446
#
# Best val_loss So Far: 0.09851892292499542
# Total elapsed time: 00h 12m 28s
# Best Hyperparameters: {'units_layer1': 256, 'dropout_rate': 0.3, 'num_layers': 2, 'units_layer2': 256, 'dropout_rate_layer2': 0.3, 'units_layer3': 64, 'dropout_rate_layer3': 0.2, 'learning_rate': 0.001, 'units_layer4': 128, 'dropout_rate_layer4': 0.4, 'units_layer5': 64, 'dropout_rate_layer5': 0.2, 'tuner/epochs': 17, 'tuner/initial_epoch': 0, 'tuner/bracket': 1, 'tuner/round': 0}
# Epoch 1/200
# 28/28 [==============================] - 3s 23ms/step - loss: 1.4876 - mae: 0.7964 - val_loss: 0.6810 - val_mae: 0.5621
# Epoch 2/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.6630 - mae: 0.5318 - val_loss: 0.3563 - val_mae: 0.4025
# Epoch 3/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.4461 - mae: 0.3995 - val_loss: 0.1907 - val_mae: 0.2556
# Epoch 4/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.2881 - mae: 0.3274 - val_loss: 0.1555 - val_mae: 0.2178
# Epoch 5/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.2433 - mae: 0.2966 - val_loss: 0.1629 - val_mae: 0.2180
# Epoch 6/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.2414 - mae: 0.2955 - val_loss: 0.1166 - val_mae: 0.1962
# Epoch 7/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.1809 - mae: 0.2569 - val_loss: 0.1440 - val_mae: 0.1931
# Epoch 8/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.1758 - mae: 0.2502 - val_loss: 0.1359 - val_mae: 0.1928
# Epoch 9/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.1782 - mae: 0.2449 - val_loss: 0.1202 - val_mae: 0.1712
# Epoch 10/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.1638 - mae: 0.2352 - val_loss: 0.1397 - val_mae: 0.1929
# Epoch 11/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.1511 - mae: 0.2247 - val_loss: 0.1325 - val_mae: 0.1728
# Epoch 12/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.1357 - mae: 0.2187 - val_loss: 0.0964 - val_mae: 0.1720
# Epoch 13/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.1288 - mae: 0.2118 - val_loss: 0.1222 - val_mae: 0.1834
# Epoch 14/200
# 28/28 [==============================] - 1s 22ms/step - loss: 0.1410 - mae: 0.2060 - val_loss: 0.1784 - val_mae: 0.2045
# Epoch 15/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.1421 - mae: 0.2092 - val_loss: 0.1147 - val_mae: 0.1669
# Epoch 16/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.1188 - mae: 0.2008 - val_loss: 0.1266 - val_mae: 0.1805
# Epoch 17/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.1188 - mae: 0.1967 - val_loss: 0.1204 - val_mae: 0.1726
# Epoch 18/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0889 - mae: 0.1792 - val_loss: 0.1235 - val_mae: 0.1696
# Epoch 19/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.1089 - mae: 0.1809 - val_loss: 0.1240 - val_mae: 0.1762
# Epoch 20/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.1133 - mae: 0.1861 - val_loss: 0.1474 - val_mae: 0.1870
# Epoch 21/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0977 - mae: 0.1803 - val_loss: 0.1093 - val_mae: 0.1523
# Epoch 22/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.1012 - mae: 0.1759 - val_loss: 0.1424 - val_mae: 0.1746
# Epoch 23/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0793 - mae: 0.1674 - val_loss: 0.1212 - val_mae: 0.1696
# Epoch 24/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0814 - mae: 0.1637 - val_loss: 0.1354 - val_mae: 0.1784
# Epoch 25/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0967 - mae: 0.1702 - val_loss: 0.1194 - val_mae: 0.1697
# Epoch 26/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0838 - mae: 0.1646 - val_loss: 0.1045 - val_mae: 0.1432
# Epoch 27/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0835 - mae: 0.1607 - val_loss: 0.1272 - val_mae: 0.1750
# Epoch 28/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0777 - mae: 0.1559 - val_loss: 0.0864 - val_mae: 0.1406
# Epoch 29/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0874 - mae: 0.1650 - val_loss: 0.0978 - val_mae: 0.1526
# Epoch 30/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0873 - mae: 0.1560 - val_loss: 0.1045 - val_mae: 0.1467
# Epoch 31/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0645 - mae: 0.1444 - val_loss: 0.1100 - val_mae: 0.1535
# Epoch 32/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0848 - mae: 0.1554 - val_loss: 0.0911 - val_mae: 0.1346
# Epoch 33/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0862 - mae: 0.1591 - val_loss: 0.1281 - val_mae: 0.1718
# Epoch 34/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0864 - mae: 0.1575 - val_loss: 0.1355 - val_mae: 0.1742
# Epoch 35/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0658 - mae: 0.1442 - val_loss: 0.1160 - val_mae: 0.1460
# Epoch 36/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0820 - mae: 0.1501 - val_loss: 0.1133 - val_mae: 0.1564
# Epoch 37/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0790 - mae: 0.1445 - val_loss: 0.1123 - val_mae: 0.1545
# Epoch 38/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0682 - mae: 0.1470 - val_loss: 0.1095 - val_mae: 0.1424
# Epoch 39/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0905 - mae: 0.1602 - val_loss: 0.0998 - val_mae: 0.1412
# Epoch 40/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0847 - mae: 0.1501 - val_loss: 0.1055 - val_mae: 0.1509
# Epoch 41/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0689 - mae: 0.1438 - val_loss: 0.1271 - val_mae: 0.1629
# Epoch 42/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0728 - mae: 0.1420 - val_loss: 0.1262 - val_mae: 0.1637
# Epoch 43/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0684 - mae: 0.1422 - val_loss: 0.0990 - val_mae: 0.1302
# Epoch 44/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0537 - mae: 0.1260 - val_loss: 0.1067 - val_mae: 0.1318
# Epoch 45/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0807 - mae: 0.1449 - val_loss: 0.1081 - val_mae: 0.1447
# Epoch 46/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0652 - mae: 0.1369 - val_loss: 0.1078 - val_mae: 0.1441
# Epoch 47/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0576 - mae: 0.1306 - val_loss: 0.1067 - val_mae: 0.1440
# Epoch 48/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0792 - mae: 0.1460 - val_loss: 0.0940 - val_mae: 0.1349
# Epoch 49/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0746 - mae: 0.1404 - val_loss: 0.1125 - val_mae: 0.1478
# Epoch 50/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0775 - mae: 0.1405 - val_loss: 0.1142 - val_mae: 0.1473
# Epoch 51/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0728 - mae: 0.1391 - val_loss: 0.1108 - val_mae: 0.1472
# Epoch 52/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.1219 - mae: 0.1566 - val_loss: 0.0925 - val_mae: 0.1348
# Epoch 53/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0738 - mae: 0.1415 - val_loss: 0.0908 - val_mae: 0.1310
# Epoch 54/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0786 - mae: 0.1413 - val_loss: 0.1048 - val_mae: 0.1413
# Epoch 55/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0641 - mae: 0.1350 - val_loss: 0.1010 - val_mae: 0.1356
# Epoch 56/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0750 - mae: 0.1401 - val_loss: 0.1094 - val_mae: 0.1409
# Epoch 57/200
# 28/28 [==============================] - 0s 8ms/step - loss: 0.0620 - mae: 0.1313 - val_loss: 0.1174 - val_mae: 0.1443
# Epoch 58/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0570 - mae: 0.1255 - val_loss: 0.1190 - val_mae: 0.1519
# Epoch 59/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0639 - mae: 0.1352 - val_loss: 0.1087 - val_mae: 0.1384
# Epoch 60/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0628 - mae: 0.1323 - val_loss: 0.1052 - val_mae: 0.1355
# Epoch 61/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0601 - mae: 0.1293 - val_loss: 0.1086 - val_mae: 0.1398
# Epoch 62/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0689 - mae: 0.1333 - val_loss: 0.1051 - val_mae: 0.1402
# Epoch 63/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0544 - mae: 0.1250 - val_loss: 0.1250 - val_mae: 0.1560
# Epoch 64/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0666 - mae: 0.1346 - val_loss: 0.1068 - val_mae: 0.1446
# Epoch 65/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0614 - mae: 0.1313 - val_loss: 0.0984 - val_mae: 0.1331
# Epoch 66/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0559 - mae: 0.1261 - val_loss: 0.1170 - val_mae: 0.1459
# Epoch 67/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0581 - mae: 0.1302 - val_loss: 0.1173 - val_mae: 0.1477
# Epoch 68/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0543 - mae: 0.1223 - val_loss: 0.1079 - val_mae: 0.1402
# Epoch 69/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0531 - mae: 0.1221 - val_loss: 0.1019 - val_mae: 0.1329
# Epoch 70/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0589 - mae: 0.1271 - val_loss: 0.1209 - val_mae: 0.1485
# Epoch 71/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0665 - mae: 0.1333 - val_loss: 0.1311 - val_mae: 0.1656
# Epoch 72/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0629 - mae: 0.1307 - val_loss: 0.1188 - val_mae: 0.1498
# Epoch 73/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0558 - mae: 0.1232 - val_loss: 0.0971 - val_mae: 0.1355
# Epoch 74/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0591 - mae: 0.1251 - val_loss: 0.1029 - val_mae: 0.1303
# Epoch 75/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0562 - mae: 0.1242 - val_loss: 0.0973 - val_mae: 0.1252
# Epoch 76/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0532 - mae: 0.1256 - val_loss: 0.0985 - val_mae: 0.1298
# Epoch 77/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0588 - mae: 0.1286 - val_loss: 0.1059 - val_mae: 0.1392
# Epoch 78/200
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0499 - mae: 0.1206 - val_loss: 0.1015 - val_mae: 0.1251
# Epoch 79/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0574 - mae: 0.1265 - val_loss: 0.1015 - val_mae: 0.1318
# Epoch 80/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0577 - mae: 0.1248 - val_loss: 0.1244 - val_mae: 0.1552
# Epoch 81/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0553 - mae: 0.1240 - val_loss: 0.1003 - val_mae: 0.1372
# Epoch 82/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0536 - mae: 0.1237 - val_loss: 0.1065 - val_mae: 0.1370
# Epoch 83/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0544 - mae: 0.1218 - val_loss: 0.1198 - val_mae: 0.1462
# Epoch 84/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0621 - mae: 0.1276 - val_loss: 0.1045 - val_mae: 0.1312
# Epoch 85/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0469 - mae: 0.1168 - val_loss: 0.0991 - val_mae: 0.1316
# Epoch 86/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0520 - mae: 0.1207 - val_loss: 0.0998 - val_mae: 0.1336
# Epoch 87/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0536 - mae: 0.1238 - val_loss: 0.1125 - val_mae: 0.1469
# Epoch 88/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0498 - mae: 0.1210 - val_loss: 0.0915 - val_mae: 0.1210
# Epoch 89/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0653 - mae: 0.1310 - val_loss: 0.1014 - val_mae: 0.1265
# Epoch 90/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0529 - mae: 0.1191 - val_loss: 0.1164 - val_mae: 0.1425
# Epoch 91/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0476 - mae: 0.1180 - val_loss: 0.1168 - val_mae: 0.1439
# Epoch 92/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0535 - mae: 0.1222 - val_loss: 0.1050 - val_mae: 0.1309
# Epoch 93/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0442 - mae: 0.1180 - val_loss: 0.0971 - val_mae: 0.1236
# Epoch 94/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0583 - mae: 0.1245 - val_loss: 0.0871 - val_mae: 0.1242
# Epoch 95/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0536 - mae: 0.1208 - val_loss: 0.0982 - val_mae: 0.1398
# Epoch 96/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0536 - mae: 0.1232 - val_loss: 0.1047 - val_mae: 0.1366
# Epoch 97/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0485 - mae: 0.1192 - val_loss: 0.1030 - val_mae: 0.1384
# Epoch 98/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0472 - mae: 0.1153 - val_loss: 0.0864 - val_mae: 0.1280
# Epoch 99/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0462 - mae: 0.1193 - val_loss: 0.0996 - val_mae: 0.1378
# Epoch 100/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0517 - mae: 0.1220 - val_loss: 0.1231 - val_mae: 0.1544
# Epoch 101/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0519 - mae: 0.1204 - val_loss: 0.0981 - val_mae: 0.1262
# Epoch 102/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0526 - mae: 0.1231 - val_loss: 0.0919 - val_mae: 0.1194
# Epoch 103/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0464 - mae: 0.1138 - val_loss: 0.1095 - val_mae: 0.1442
# Epoch 104/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0538 - mae: 0.1227 - val_loss: 0.1163 - val_mae: 0.1465
# Epoch 105/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0477 - mae: 0.1187 - val_loss: 0.1096 - val_mae: 0.1425
# Epoch 106/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0482 - mae: 0.1161 - val_loss: 0.1055 - val_mae: 0.1363
# Epoch 107/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0489 - mae: 0.1179 - val_loss: 0.1063 - val_mae: 0.1319
# Epoch 108/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0471 - mae: 0.1156 - val_loss: 0.1013 - val_mae: 0.1298
# Epoch 109/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0483 - mae: 0.1169 - val_loss: 0.0909 - val_mae: 0.1154
# Epoch 110/200
# 28/28 [==============================] - 0s 8ms/step - loss: 0.0407 - mae: 0.1113 - val_loss: 0.0925 - val_mae: 0.1257
# Epoch 111/200
# 28/28 [==============================] - 0s 8ms/step - loss: 0.0464 - mae: 0.1134 - val_loss: 0.0882 - val_mae: 0.1197
# Epoch 112/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0425 - mae: 0.1138 - val_loss: 0.0886 - val_mae: 0.1301
# Epoch 113/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0490 - mae: 0.1199 - val_loss: 0.0919 - val_mae: 0.1247
# Epoch 114/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0521 - mae: 0.1239 - val_loss: 0.0995 - val_mae: 0.1238
# Epoch 115/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0413 - mae: 0.1131 - val_loss: 0.0932 - val_mae: 0.1181
# Epoch 116/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0471 - mae: 0.1166 - val_loss: 0.0967 - val_mae: 0.1259
# Epoch 117/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0435 - mae: 0.1135 - val_loss: 0.0865 - val_mae: 0.1149
# Epoch 118/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0538 - mae: 0.1254 - val_loss: 0.0848 - val_mae: 0.1206
# Epoch 119/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0499 - mae: 0.1198 - val_loss: 0.0945 - val_mae: 0.1250
# Epoch 120/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0440 - mae: 0.1149 - val_loss: 0.0937 - val_mae: 0.1186
# Epoch 121/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0465 - mae: 0.1177 - val_loss: 0.1001 - val_mae: 0.1296
# Epoch 122/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0550 - mae: 0.1207 - val_loss: 0.0956 - val_mae: 0.1215
# Epoch 123/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0475 - mae: 0.1152 - val_loss: 0.0907 - val_mae: 0.1181
# Epoch 124/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0450 - mae: 0.1157 - val_loss: 0.0953 - val_mae: 0.1180
# Epoch 125/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0378 - mae: 0.1100 - val_loss: 0.1063 - val_mae: 0.1266
# Epoch 126/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0447 - mae: 0.1173 - val_loss: 0.1051 - val_mae: 0.1274
# Epoch 127/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0478 - mae: 0.1186 - val_loss: 0.0943 - val_mae: 0.1162
# Epoch 128/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0466 - mae: 0.1193 - val_loss: 0.0909 - val_mae: 0.1153
# Epoch 129/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0427 - mae: 0.1128 - val_loss: 0.0943 - val_mae: 0.1201
# Epoch 130/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0541 - mae: 0.1229 - val_loss: 0.0904 - val_mae: 0.1125
# Epoch 131/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0456 - mae: 0.1195 - val_loss: 0.0882 - val_mae: 0.1130
# Epoch 132/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0388 - mae: 0.1115 - val_loss: 0.0943 - val_mae: 0.1230
# Epoch 133/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0422 - mae: 0.1107 - val_loss: 0.0897 - val_mae: 0.1143
# Epoch 134/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0437 - mae: 0.1157 - val_loss: 0.0992 - val_mae: 0.1167
# Epoch 135/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0457 - mae: 0.1144 - val_loss: 0.1106 - val_mae: 0.1194
# Epoch 136/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0466 - mae: 0.1168 - val_loss: 0.1066 - val_mae: 0.1251
# Epoch 137/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0427 - mae: 0.1104 - val_loss: 0.1083 - val_mae: 0.1292
# Epoch 138/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0457 - mae: 0.1184 - val_loss: 0.1072 - val_mae: 0.1272
# Epoch 139/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0426 - mae: 0.1145 - val_loss: 0.1043 - val_mae: 0.1164
# Epoch 140/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0411 - mae: 0.1128 - val_loss: 0.1070 - val_mae: 0.1215
# Epoch 141/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0517 - mae: 0.1255 - val_loss: 0.1156 - val_mae: 0.1239
# Epoch 142/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0476 - mae: 0.1188 - val_loss: 0.1056 - val_mae: 0.1315
# Epoch 143/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0468 - mae: 0.1161 - val_loss: 0.1001 - val_mae: 0.1218
# Epoch 144/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0493 - mae: 0.1183 - val_loss: 0.1039 - val_mae: 0.1215
# Epoch 145/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0502 - mae: 0.1227 - val_loss: 0.1012 - val_mae: 0.1237
# Epoch 146/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0472 - mae: 0.1177 - val_loss: 0.1056 - val_mae: 0.1327
# Epoch 147/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0446 - mae: 0.1169 - val_loss: 0.1112 - val_mae: 0.1261
# Epoch 148/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0470 - mae: 0.1155 - val_loss: 0.1082 - val_mae: 0.1271
# Epoch 149/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0424 - mae: 0.1142 - val_loss: 0.1011 - val_mae: 0.1206
# Epoch 150/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0455 - mae: 0.1174 - val_loss: 0.1119 - val_mae: 0.1310
# Epoch 151/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0551 - mae: 0.1252 - val_loss: 0.1153 - val_mae: 0.1214
# Epoch 152/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0392 - mae: 0.1136 - val_loss: 0.1114 - val_mae: 0.1291
# Epoch 153/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0373 - mae: 0.1116 - val_loss: 0.1351 - val_mae: 0.1284
# Epoch 154/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0392 - mae: 0.1110 - val_loss: 0.1242 - val_mae: 0.1285
# Epoch 155/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0495 - mae: 0.1216 - val_loss: 0.1283 - val_mae: 0.1355
# Epoch 156/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0441 - mae: 0.1155 - val_loss: 0.1449 - val_mae: 0.1566
# Epoch 157/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0425 - mae: 0.1143 - val_loss: 0.1322 - val_mae: 0.1278
# Epoch 158/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0447 - mae: 0.1176 - val_loss: 0.1223 - val_mae: 0.1212
# Epoch 159/200
# 28/28 [==============================] - 1s 18ms/step - loss: 0.0488 - mae: 0.1183 - val_loss: 0.1065 - val_mae: 0.1146
# Epoch 160/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0420 - mae: 0.1187 - val_loss: 0.1228 - val_mae: 0.1368
# Epoch 161/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0416 - mae: 0.1159 - val_loss: 0.1235 - val_mae: 0.1201
# Epoch 162/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0402 - mae: 0.1172 - val_loss: 0.1195 - val_mae: 0.1323
# Epoch 163/200
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0391 - mae: 0.1107 - val_loss: 0.1149 - val_mae: 0.1194
# Epoch 164/200
# 28/28 [==============================] - 0s 18ms/step - loss: 0.0389 - mae: 0.1138 - val_loss: 0.1276 - val_mae: 0.1359
# Epoch 165/200
# 28/28 [==============================] - 1s 22ms/step - loss: 0.0411 - mae: 0.1148 - val_loss: 0.1170 - val_mae: 0.1260
# Epoch 166/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0377 - mae: 0.1103 - val_loss: 0.1312 - val_mae: 0.1355
# Epoch 167/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0356 - mae: 0.1093 - val_loss: 0.1242 - val_mae: 0.1281
# Epoch 168/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0408 - mae: 0.1150 - val_loss: 0.1265 - val_mae: 0.1243
# Epoch 169/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0400 - mae: 0.1130 - val_loss: 0.1293 - val_mae: 0.1334
# Epoch 170/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0427 - mae: 0.1180 - val_loss: 0.1178 - val_mae: 0.1313
# Epoch 171/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0286 - mae: 0.1035 - val_loss: 0.1224 - val_mae: 0.1205
# Epoch 172/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0414 - mae: 0.1153 - val_loss: 0.1590 - val_mae: 0.1338
# Epoch 173/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0447 - mae: 0.1166 - val_loss: 0.1299 - val_mae: 0.1231
# Epoch 174/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0415 - mae: 0.1149 - val_loss: 0.1349 - val_mae: 0.1371
# Epoch 175/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0395 - mae: 0.1143 - val_loss: 0.1293 - val_mae: 0.1383
# Epoch 176/200
# 28/28 [==============================] - 1s 19ms/step - loss: 0.0410 - mae: 0.1161 - val_loss: 0.1309 - val_mae: 0.1313
# Epoch 177/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0401 - mae: 0.1151 - val_loss: 0.1272 - val_mae: 0.1272
# Epoch 178/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0423 - mae: 0.1148 - val_loss: 0.1308 - val_mae: 0.1289
# Epoch 179/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0388 - mae: 0.1112 - val_loss: 0.1245 - val_mae: 0.1253
# Epoch 180/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0411 - mae: 0.1161 - val_loss: 0.1289 - val_mae: 0.1414
# Epoch 181/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0395 - mae: 0.1145 - val_loss: 0.1319 - val_mae: 0.1289
# Epoch 182/200
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0555 - mae: 0.1245 - val_loss: 0.1102 - val_mae: 0.1259
# Epoch 183/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0479 - mae: 0.1205 - val_loss: 0.1063 - val_mae: 0.1167
# Epoch 184/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0441 - mae: 0.1174 - val_loss: 0.1219 - val_mae: 0.1267
# Epoch 185/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0430 - mae: 0.1194 - val_loss: 0.1277 - val_mae: 0.1263
# Epoch 186/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0438 - mae: 0.1186 - val_loss: 0.1335 - val_mae: 0.1229
# Epoch 187/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0404 - mae: 0.1161 - val_loss: 0.1330 - val_mae: 0.1247
# Epoch 188/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0459 - mae: 0.1224 - val_loss: 0.1351 - val_mae: 0.1339
# Epoch 189/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0436 - mae: 0.1204 - val_loss: 0.1430 - val_mae: 0.1272
# Epoch 190/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0407 - mae: 0.1180 - val_loss: 0.1233 - val_mae: 0.1272
# Epoch 191/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0463 - mae: 0.1181 - val_loss: 0.1100 - val_mae: 0.1169
# Epoch 192/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0448 - mae: 0.1219 - val_loss: 0.1340 - val_mae: 0.1384
# Epoch 193/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0420 - mae: 0.1165 - val_loss: 0.1502 - val_mae: 0.1299
# Epoch 194/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0370 - mae: 0.1128 - val_loss: 0.1505 - val_mae: 0.1422
# Epoch 195/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0407 - mae: 0.1190 - val_loss: 0.1452 - val_mae: 0.1380
# Epoch 196/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0463 - mae: 0.1213 - val_loss: 0.1384 - val_mae: 0.1370
# Epoch 197/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0346 - mae: 0.1115 - val_loss: 0.1643 - val_mae: 0.1389
# Epoch 198/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0386 - mae: 0.1143 - val_loss: 0.1588 - val_mae: 0.1587
# Epoch 199/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0425 - mae: 0.1177 - val_loss: 0.1514 - val_mae: 0.1383
# Epoch 200/200
# 28/28 [==============================] - 0s 10ms/step - loss: 0.0361 - mae: 0.1125 - val_loss: 0.1389 - val_mae: 0.1340

# %%
# !pwd
# Out:
# /c/Users/rah10/University of Oregon Dropbox/Rebecca Hayes/pollenGeolocation

# %%
# Save the model in HDF5 format
model.save("../pollenGeolocation_saved/best_mlp_model.h5")

# %%
# Make predictions
predictions = model.predict(X_test)

# Create a figure and an axis
fig, ax = plt.subplots(figsize=(8, 6))

plot_test_preds(y_test, predictions, sc_y, "MLP",ax=ax)
# Out:
# 9/9 [==============================] - 1s 9ms/step

# %% [markdown]
# # Linear regression
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.MultiTaskLasso.html

# %%
# Create a figure and an axis
fig, ax = plt.subplots(figsize=(8, 6))

MTKNReg = linear_model.MultiTaskLasso(alpha=0.1)
MTKNReg.fit(X_train, y_train)
preds_LR = MTKNReg.predict(X_test)


LR_rsq = r2_score(y_test,preds_LR)
LR_mse = mean_squared_error(y_test,preds_LR)
distances_LR = [geodesic(real, pred).kilometers for real, pred in zip(y_test, preds_LR)]
avg_distance_LR = np.mean(distances_LR)
se_distance_LR = np.std(distances_LR) 


plot_test_preds(y_test, preds_LR, sc_y, "Linear Regression",ax=ax)

# %% [markdown]
# # SVR Support Vector Regression multioutput regressor
# https://medium.com/pursuitnotes/support-vector-regression-in-6-steps-with-python-c4569acd062d
# https://scikit-learn.org/stable/modules/svm.html#regression
# https://datascience.stackexchange.com/questions/82743/valueerror-y-should-be-a-1d-array-got-an-array-of-shape-285-30-instead
# https://www.section.io/engineering-education/support-vector-regression-in-python/

# %%
# Create a figure and an axis
fig, ax = plt.subplots(figsize=(8, 6))

# Create the SVR regressor
svr = SVR(epsilon=0.01)

# Create the Multioutput Regressor
mor = MultiOutputRegressor(svr)

# Train the regressor
mor = mor.fit(X_train, y_train)

# Generate predictions for testing data
preds_SVR = mor.predict(X_test)

SVR_rsq = r2_score(y_test,preds_SVR)
SVR_mse = mean_squared_error(y_test,preds_SVR)
distances_SVR = [geodesic(real, pred).kilometers for real, pred in zip(y_test, preds_SVR)]
avg_distance_SVR = np.mean(distances_SVR)
se_distance_SVR = np.std(distances_SVR) 

plot_test_preds(y_test, preds_SVR, sc_y, "Support Vector Regression", ax=ax)

# %% [markdown]
# # k-Nearest Neighbors for Multioutput Regression
# https://machinelearningmastery.com/multi-output-regression-models-with-python/

# %%
# Create a figure and an axis
fig, ax = plt.subplots(figsize=(8, 6))

# fit model
KNR = KNeighborsRegressor(algorithm='auto', weights='distance') #slightly better when weighted by distance
KNR = KNR.fit(X_train, y_train)

preds_KNR = KNR.predict(X_test)

KNR_rsq = r2_score(y_test,preds_KNR)
KNR_mse = mean_squared_error(y_test,preds_KNR)
distances_KNR = [geodesic(real, pred).kilometers for real, pred in zip(y_test, preds_KNR)]
avg_distance_KNR = np.mean(distances_KNR)
se_distance_KNR = np.std(distances_KNR) 

plot_test_preds(y_test, preds_KNR, sc_y, "k-Nearest Neighbors", ax=ax)

# %% [markdown]
# # Decision Tree for multioutput regression

# %%
# Create a figure and an axis
fig, ax = plt.subplots(figsize=(8, 6))

# fit model
DTR = DecisionTreeRegressor(max_depth=5)
DTR = DTR.fit(X_train, y_train)

preds_DTR = DTR.predict(X_test)

DTR_rsq = r2_score(y_test,preds_DTR)
DTR_mse = mean_squared_error(y_test,preds_DTR)
distances_DTR = [geodesic(real, pred).kilometers for real, pred in zip(y_test, preds_DTR)]
avg_distance_DTR = np.mean(distances_DTR)
se_distance_DTR = np.std(distances_DTR) 


plot_test_preds(y_test, preds_DTR, sc_y, "Decision Tree", ax=ax)

# %%
#Random forest
# Create a figure and an axis
fig, ax = plt.subplots(figsize=(8, 6))

# Using tuned model
rf =RandomForestRegressor(n_estimators = 400,
                          min_samples_split = 2, 
                          min_samples_leaf = 1, 
                          max_features = 'sqrt', 
                          max_depth = None, 
                          bootstrap = False) 
rf = rf.fit(X_train,y_train)

pred_train = rf.predict(X_train)
preds_RF = rf.predict(X_test)

RF_rsq = r2_score(y_test,preds_RF)
RF_mse = mean_squared_error(y_test,preds_RF)
distances_RF = [geodesic(real, pred).kilometers for real, pred in zip(y_test, preds_RF)]
avg_distance_RF = np.mean(distances_RF)
se_distance_RF = np.std(distances_RF) 

plot_test_preds(y_test, preds_RF, sc_y, "Random Forest", ax=ax)

# %% [markdown]
# https://towardsdatascience.com/hyperparameter-tuning-the-random-forest-in-python-using-scikit-learn-28d2aa77dd74

# %%
RF_tuning = False
if RF_tuning == True:
    from sklearn.model_selection import RandomizedSearchCV
    # Number of trees in random forest
    n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
    # Number of features to consider at every split
    max_features = ['auto', 'sqrt']
    # Maximum number of levels in tree
    max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
    max_depth.append(None)
    # Minimum number of samples required to split a node
    min_samples_split = [2, 5, 10]
    # Minimum number of samples required at each leaf node
    min_samples_leaf = [1, 2, 4]
    # Method of selecting samples for training each tree
    bootstrap = [True, False]
    # Create the random grid
    random_grid = {'n_estimators': n_estimators,
                'max_features': max_features,
                'max_depth': max_depth,
                'min_samples_split': min_samples_split,
                'min_samples_leaf': min_samples_leaf,
                'bootstrap': bootstrap}
    print(random_grid)

    rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)
    # Fit the random search model
    rf_random.fit(X_train, y_train)

    rf_random.best_params_

# %% [markdown]
# XGBoost

# %%
from xgboost import XGBRegressor

# Create a figure and an axis
fig, ax = plt.subplots(figsize=(8, 6))

# Create the base XGBoost regressor
xgb = XGBRegressor(objective='reg:squarederror', random_state=42)

# Wrap with MultiOutputRegressor for multioutput regression
multi_xgb = MultiOutputRegressor(xgb)

# Train the model
multi_xgb.fit(X_train, y_train)

# Generate predictions
preds_xg = multi_xgb.predict(X_test)

XG_rsq = r2_score(y_test,preds_xg)
XG_mse = mean_squared_error(y_test,preds_xg)

plot_test_preds(y_test, preds_xg, sc_y, "XGBoost", ax=ax)

# %%
tune_XG = True

if tune_XG == True:
    # hyperparam tuning for xgboost
    # Example hyperparameter grid for XGBRegressor
    param_grid = {
        'estimator__n_estimators': [50, 100, 200],
        'estimator__max_depth': [3, 5, 7],
        'estimator__learning_rate': [0.01, 0.1, 0.2],
        'estimator__subsample': [0.8, 1.0],
        'estimator__colsample_bytree': [0.8, 1.0],
        'estimator__reg_alpha': [0, 0.1, 1],  # L1 regularization
        'estimator__reg_lambda': [0.1, 1, 10],  # L2 regularization
    }
    # Set up RandomizedSearchCV
    xgb_random = RandomizedSearchCV(
        estimator=multi_xgb,
        param_distributions=param_grid,
        n_iter=100,  # Number of parameter settings sampled
        cv=3,        # 3-fold cross-validation
        verbose=2,
        random_state=42,
        n_jobs=-1    # Use all available cores
    )
    # Fit the RandomizedSearchCV
    xgb_random.fit(X_train, y_train)

    # Get the best parameters
    print("Best parameters found: ", xgb_random.best_params_)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Best parameters found:  {'estimator__subsample': 0.8, 'estimator__reg_lambda': 10, 'estimator__reg_alpha': 0, 'estimator__n_estimators': 200, 'estimator__max_depth': 7, 'estimator__learning_rate': 0.1, 'estimator__colsample_bytree': 0.8}

# %%
# Create a figure and an axis
fig, ax = plt.subplots(figsize=(8, 6))

# Get predictions using the best estimator
best_xgb = xgb_random.best_estimator_
preds_XG_best = best_xgb.predict(X_test)

XG_rsq_best = r2_score(y_test,preds_XG_best)
XG_mse_best = mean_squared_error(y_test,preds_XG_best)
distances_XG = [geodesic(real, pred).kilometers for real, pred in zip(y_test, preds_XG_best)]
avg_distance_XG = np.mean(distances_XG)
se_distance_XG = np.std(distances_XG) 

plot_test_preds(y_test, preds_XG_best, sc_y, "XGBoost", ax=ax)

# %%
method = ['Linear Regression', 
          'SVR Support Vector Regression' , 
          'Decision Tree', 
          'k-Nearest Neighbors', 
          'XGBoost', 
          'Random Forest'
          ]
rsquared = [LR_rsq, 
            SVR_rsq, 
            DTR_rsq,
            KNR_rsq, 
            XG_rsq_best,
            RF_rsq]
MSE = [LR_mse, 
       SVR_mse, 
       DTR_mse,
       KNR_mse, 
       XG_mse_best,
       RF_mse]
dist = [avg_distance_LR,
        avg_distance_SVR,
        avg_distance_DTR,
        avg_distance_KNR,
        avg_distance_XG,
        avg_distance_RF]

se = [se_distance_LR,
      se_distance_SVR,
      se_distance_DTR,
      se_distance_KNR,
      se_distance_XG,
      se_distance_RF]

df = pd.DataFrame({'Model' : method,
              'r2' : rsquared,
              'MSE' : MSE
              })
df

df.to_csv("tables/model_results.csv")

# %%
import seaborn as sns
df
# Out:
#                            Model        r2       MSE
# 0              Linear Regression  0.787219  0.160096
# 1  SVR Support Vector Regression  0.793520  0.155077
# 2                  Decision Tree  0.905538  0.069867
# 3            k-Nearest Neighbors  0.937985  0.046122
# 4                        XGBoost  0.942988  0.042568
# 5                  Random Forest  0.971803  0.020840

# %%
# Combine data into a DataFrame
data = {
    "model": ["Linear Regression"] * len(distances_LR) +
             ["SVR"] * len(distances_SVR) +
             ["Decision Tree"] * len(distances_DTR) +
             ["k-NN"] * len(distances_KNR) +
             ["XGBoost"] * len(distances_XG) +
             ["Random Forest"] * len(distances_RF),
    "distance_loss": distances_LR + distances_SVR + distances_DTR + distances_KNR + distances_XG +
                     distances_RF,
    "distance_std": se_distance_LR + se_distance_SVR + se_distance_DTR + se_distance_KNR + se_distance_XG + se_distance_RF
}

df = pd.DataFrame(data)


# Combine data into a DataFrame
data = {
    "model": ["Linear Regression"] * len(distances_LR) +
             ["SVR"] * len(distances_SVR) +
             ["Decision Tree"] * len(distances_DTR) +
             ["k-NN"] * len(distances_KNR) +
             ["XGBoost"] * len(distances_XG) +
             ["Random Forest"] * len(distances_RF),
    "distance_loss": distances_LR + distances_SVR + distances_DTR + distances_KNR + distances_XG +
                     distances_RF,
}

df = pd.DataFrame(data)

# Compute means and standard deviations
summary_stats = df.groupby("model")["distance_loss"].agg(mean="mean", std="std").reset_index()

# Create the bar chart
plt.figure(figsize=(10, 6))
sns.barplot(data=summary_stats, x="model", y="mean", palette="inferno", ci=None)

# Add custom error bars for standard deviation
plt.errorbar(
    x=range(len(summary_stats)),  # X-coordinates of bars
    y=summary_stats["mean"],  # Mean values
    yerr=summary_stats["std"],  # Standard deviations
    fmt="none",  # No markers for the error bars
    c="black",  # Color of error bars
    capsize=5,  # Length of the caps on the error bars
)

# Overlay individual data points for clarity
sns.stripplot(data=df, x="model", y="distance_loss", color="black", size=7, jitter=True, alpha=0.2)


# Add labels and title
plt.xlabel("Machine Learning Model", fontsize=12)
plt.ylabel("Geographic Distance Loss (km)", fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %%
df_LR = pd.DataFrame(df.distance_loss[df.model == 'Linear Regression'])
df_SVR = pd.DataFrame(df.distance_loss[df.model == 'SVR'])
df_DT = pd.DataFrame(df.distance_loss[df.model == 'Decision Tree'])
df_KNN = pd.DataFrame(df.distance_loss[df.model == 'k-NN'])
df_XG = pd.DataFrame(df.distance_loss[df.model == 'XGBoost'])
df_RF = pd.DataFrame(df.distance_loss[df.model == 'Random Forest'])

df_models = [("Linear Regression", df_LR),
             ("SVR", df_SVR),
             ("Decision Tree", df_DT),
             ("k-NN", df_KNN),
             ("XGBoost", df_XG),
             ("Random Forest", df_RF)]

# %%
# Normalize color scale across all heatmaps
vmin = min([df.min().min() for _, df in df_models])
vmax = max([df.max().max() for _, df in df_models])

# Create the figure and axes
fig, axes = plt.subplots(len(df_models), 1, figsize=(12, 15), sharex=True, constrained_layout=True)

# Create a shared colorbar axis
cbar_ax = fig.add_axes([1.01, 0.1, 0.02, 0.8])  # Adjust position and size of the colorbar

# Loop through models and plot each heatmap
for ax, (model_name, data) in zip(axes, df_models):
    sns.heatmap(data.T, ax=ax, cmap="magma", cbar=False, vmin=vmin, vmax=vmax, xticklabels=False, yticklabels=False)
    ax.set_ylabel(model_name, fontsize=16)

# Add the shared colorbar
sm = plt.cm.ScalarMappable(cmap="magma", norm=plt.Normalize(vmin=vmin, vmax=vmax))
cbar = fig.colorbar(sm, cax=cbar_ax)
cbar.set_label('Distance Loss (km)', fontsize=16)

# Add a common X-axis label
axes[-1].set_xlabel("Test Sample", fontsize=16)

plt.show()

# %%
# plot real vs predicted scatterplots for each model 

method_dict = {'Linear Regression':preds_LR, 
          'SVR Support Vector Regression':preds_SVR ,  
          'Decision Tree':preds_DTR, 
          'k-Nearest Neighbors':preds_KNR, 
          'XGBoost':preds_XG_best,
          'Random Forest':preds_RF}

scaler = sc_y

# Create a 3x2 grid of subplots
fig, axes = plt.subplots(3, 2, figsize=(12, 15))  # 3 rows, 2 columns
axes = axes.flatten()  # Flatten the 2D array for easy iteration

# Iterate over method_dict to access both model_type and associated preds
for i, (model_type, preds) in enumerate(method_dict.items()):
    ax = axes[i]  # Get the subplot axis
    plot_test_preds(y_test, preds, sc_y, model_type, ax=ax)  # Call the plot function

    # Add panel label in the upper left corner
    ax.text(
        -0.15, 1.1,  # Coordinates in axis-relative units (-0.1 from left, 1.1 above top)
        f"{ascii_uppercase[i]}.",  # Label: A., B., C., ...
        transform=ax.transAxes,  # Use axis-relative coordinates
        fontsize=20,  # Font size
        va='top',  # Vertical alignment
        ha='left'  # Horizontal alignment
    )


# Adjust layout for better spacing
plt.tight_layout()

# Save the plot as a PDF (make sure to do this after plt.show() or tight_layout)
plt.savefig("../pollenGeolocation_saved/figs/real_vs_pred_scatterplots.pdf", format="pdf")

plt.show()

# %%
# TODO plot the distance between real and predicted values for all models together 
# envisioning a boxplot or violin plot with distance bt real and preds as the y and on the x would be
# each model with its own violin

# %%
# TODO add random forest map plot with arrows connecting predicted to real
